# %% [markdown]
# # Modelo de aprendizado de máquina para Íris

# %% [markdown]
# Importando o dataset e mostrando as 5 primeiras linhas

# %%
import pandas as pd

# Lendo o arquivo corretamente - a primeira linha é dados, não cabeçalho
df = pd.read_csv('https://raw.githubusercontent.com/marcelovca90-inatel/AG2/refs/heads/main/iris.csv')


pd.set_option('display.width', 1000)
print(df.head())
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm      species
# 0              5.1             3.5              1.4             0.2  Iris-setosa
# 1              4.9             3.0              1.4             0.2  Iris-setosa
# 2              4.7             3.2              1.3             0.2  Iris-setosa
# 3              4.6             3.1              1.5             0.2  Iris-setosa
# 4              5.0             3.6              1.4             0.2  Iris-setosa

# %%
# Mapeamento das espécies para números inteiros
mapeamento_especies = {
    'Iris-setosa': 1,
    'Iris-versicolor': 2, 
    'Iris-virginica': 3
}

# Aplicando o mapeamento (criando uma nova coluna ou substituindo)
df['species'] = df['species'].replace(mapeamento_especies)

pd.set_option('display.width', 1000)
print(df.head())
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  species
# 0              5.1             3.5              1.4             0.2        1
# 1              4.9             3.0              1.4             0.2        1
# 2              4.7             3.2              1.3             0.2        1
# 3              4.6             3.1              1.5             0.2        1
# 4              5.0             3.6              1.4             0.2        1
# C:\Users\gusta\AppData\Local\Temp\ipykernel_12460\1764909486.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['species'] = df['species'].replace(mapeamento_especies)
